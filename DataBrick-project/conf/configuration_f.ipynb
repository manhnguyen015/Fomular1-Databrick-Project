# %% [markdown]
# ## Folder path

# %%
raw_folder_path = "abfss://raw@fomular1dl1.dfs.core.windows.net"
processed_folder_path = "abfss://processed@fomular1dl1.dfs.core.windows.net"
presentation_folder_path = "abfss://presentation@fomular1dl1.dfs.core.windows.net"
